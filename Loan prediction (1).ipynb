# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"D:\loan_prediction.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.sample(5)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 355  LP002144  Female      No        NaN  Graduate            No
# 525  LP002699    Male     Yes          2  Graduate           Yes
# 105  LP001367    Male     Yes          1  Graduate            No
# 221  LP001743    Male     Yes          2  Graduate            No
# 181  LP001634    Male      No          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 355             3813                0.0       116.0             180.0
# 525            17500                0.0       400.0             360.0
# 105             3052             1030.0       100.0             360.0
# 221             4009             1717.0       116.0             360.0
# 181             1916             5063.0        67.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 355             1.0         Urban           Y
# 525             1.0         Rural           Y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
df.dropna(axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.loc[:,['Loan_ID','Gender']]
# Out:
#       Loan_ID  Gender
# 1    LP001003    Male
# 2    LP001005    Male
# 3    LP001006    Male
# 4    LP001008    Male
# 5    LP001011    Male
# ..        ...     ...
# 609  LP002978  Female
# 610  LP002979    Male
# 611  LP002983    Male
# 612  LP002984    Male
# 613  LP002990  Female
#
# [480 rows x 2 columns]

# %%
df.loc[1:5,['Loan_ID','Gender']]
# Out:
#     Loan_ID Gender
# 1  LP001003   Male
# 2  LP001005   Male
# 3  LP001006   Male
# 4  LP001008   Male
# 5  LP001011   Male

# %%
df.iloc[0:6,0:2]
# Out:
#     Loan_ID Gender
# 1  LP001003   Male
# 2  LP001005   Male
# 3  LP001006   Male
# 4  LP001008   Male
# 5  LP001011   Male
# 6  LP001013   Male

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['ApplicantIncome'].max()
# Out:
# 81000

# %%
df['ApplicantIncome'].min()
# Out:
# 150

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['ApplicantIncome'].mean()
# Out:
# 5364.23125

# %%
df['ApplicantIncome'].median()
# Out:
# 3859.0

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Loan_ID'].count()
# Out:
# 480

# %%
df.drop([613,612], axis=0, inplace=True)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.drop('Dependents',axis=1)
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# 5    LP001011    Male     Yes      Graduate           Yes             5417
# ..        ...     ...     ...           ...           ...              ...
# 607  LP002964    Male     Yes  Not Graduate            No             3987
# 608  LP002974    Male     Yes      Graduate            No             3232
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
#
# ...

# %%
df['Education'].value_counts()
# Out:
# Graduate        381
# Not Graduate     97
# Name: Education, dtype: int64

# %%
df.rename(columns={'Loan_ID':'LoanId'},inplace=True)

# %%
df
# Out:
#        LoanId  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.columns
# Out:
# Index(['LoanId', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df[(df['LoanAmount'] >=100) & (df['Self_Employed']=='Yes')]
# Out:
#        LoanId  Gender Married Dependents     Education Self_Employed  \
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 25   LP001066    Male     Yes          0      Graduate           Yes
# 32   LP001097    Male      No          1      Graduate           Yes
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 62   LP001207    Male     Yes          0  Not Graduate           Yes
# 68   LP001238    Male     Yes         3+  Not Graduate           Yes
# 74   LP001253    Male     Yes         3+      Graduate           Yes
# 77   LP001259    Male     Yes          1      Graduate           Yes
# 128  LP001451    Male     Yes          1      Graduate           Yes
# 142  LP001504    Male      No          0      Graduate           Yes
# 151  LP001529    Male     Yes          0      Graduate           Yes
# 185  LP001640    Male     Yes          0      Graduate           Yes
# 212  LP001713    Male     Yes          1      Graduate           Yes
# ...

# %%
df['ApplicantIncome'].std()
# Out:
# 5679.099941799567

# %%
df['ApplicantIncome'].mode()
# Out:
# 0    2500
# Name: ApplicantIncome, dtype: int64

# %%
df.dtypes
# Out:
# LoanId                object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.corr()
# Out:
# C:\Users\ruthr\AppData\Local\Temp\ipykernel_22600\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.112373    0.495081
# CoapplicantIncome        -0.112373           1.000000    0.191426
# LoanAmount                0.495081           0.191426    1.000000
# Loan_Amount_Term         -0.010988          -0.005082    0.050672
# Credit_History           -0.057556          -0.011310   -0.042237
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.010988       -0.057556
# CoapplicantIncome         -0.005082       -0.011310
# LoanAmount                 0.050672       -0.042237
# Loan_Amount_Term           1.000000        0.034316
# ...

# %%
df.sort_values(by="LoanAmount",ascending=False)
# Out:
#        LoanId  Gender Married Dependents     Education Self_Employed  \
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 155  LP001536    Male     Yes         3+      Graduate            No
# 369  LP002191    Male     Yes          0      Graduate            No
# 487  LP002547    Male     Yes          1      Graduate            No
# 604  LP002959  Female     Yes          1      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 555  LP002792    Male     Yes          1      Graduate            No
# 133  LP001482    Male     Yes          0      Graduate           Yes
# 94   LP001325    Male      No          0  Not Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# 568  LP002840  Female      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.to_csv("Final_Loan.csv")
